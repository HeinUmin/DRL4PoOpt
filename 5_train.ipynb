# %%
import pandas as pd

train_data = pd.DataFrame()
test_data = pd.DataFrame()
result_dir=""

# %store -r train_data
# %store -r test_data
# %store -r result_dir

train_data
# Out:
#             date    fund     nav  \
# 0     2014-01-02  050025  1.2765
# 0     2014-01-02  160719  0.6600
# 0     2014-01-02  163813  0.8520
# 0     2014-01-02  164701  0.6410
# 0     2014-01-02  270023  1.3690
# ...          ...     ...     ...
# 1832  2021-12-31  270042  4.5991
# 1832  2021-12-31  290012  1.5190
# 1832  2021-12-31  320013  1.0010
# 1832  2021-12-31  519185  1.0717
# 1832  2021-12-31  539001  1.8281
#
#                                                     cov
# 0     [[0.33468638608556567, 0.06816936360615063, 0....
# 0     [[0.33468638608556567, 0.06816936360615063, 0....
# 0     [[0.33468638608556567, 0.06816936360615063, 0....
# 0     [[0.33468638608556567, 0.06816936360615063, 0....
# 0     [[0.33468638608556567, 0.06816936360615063, 0....
# ...                                                 ...
# 1832  [[0.22230073925821153, 0.04400374276624217, 0....
# 1832  [[0.22230073925821153, 0.04400374276624217, 0....
# 1832  [[0.22230073925821153, 0.04400374276624217, 0....
# 1832  [[0.22230073925821153, 0.04400374276624217, 0....
# 1832  [[0.22230073925821153, 0.04400374276624217, 0....
#
# [18330 rows x 4 columns]

# %%
fund_dimension = len(train_data["fund"].unique())
state_space = fund_dimension
print(f"Fund Dimension: {fund_dimension}, State Space: {state_space}")
# Out:
# Fund Dimension: 10, State Space: 10

# %%
from env_portfolio import PortfolioEnv
from models import DRLAgent
from config import config


weights_initial = [1 / fund_dimension] * fund_dimension


env_kwargs = {
    "hmax": 100000,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "fund_dim": fund_dimension,
    "tech_indicator_list": [],
    "action_space": fund_dimension,
    "reward_scaling": 0,
    "initial_weights": [1 / fund_dimension] * fund_dimension,
    "turbulence_threshold": config.RISK_FREE_RATE,
    "lookback": config.APPROX_BDAYS_PER_YEAR,
    "result_dir": result_dir,
}


e_train_gym = PortfolioEnv(df=train_data, **env_kwargs)


env_train, _ = e_train_gym.get_sb_env()


agent = DRLAgent(env=env_train)

# %%
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c", model_kwargs=A2C_PARAMS)
trained_a2c = agent.train_model(
    model=model_a2c, tb_log_name="a2c", total_timesteps=50000
)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
#       2 model_a2c = agent.get_model(model_name="a2c", model_kwargs=A2C_PARAMS)
# ----> 3 trained_a2c = agent.train_model(
#       4     model=model_a2c, tb_log_name="a2c", total_timesteps=50000
#       5 )
#
# File d:\wyh21\Code\DRL\models.py:103, in DRLAgent.train_model(self, model, tb_log_name, total_timesteps)
#     102 def train_model(self, model, tb_log_name, total_timesteps=5000):
# --> 103     model = model.learn(total_timesteps=total_timesteps, tb_log_name=tb_log_name)
#     104     return model
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\stable_baselines3\a2c\a2c.py:201, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     192 def learn(
#     193     self: SelfA2C,
#     194     total_timesteps: int,
#    (...)
#     199     progress_bar: bool = False,
#     200 ) -> SelfA2C:
# --> 201     return super().learn(
#     202         total_timesteps=total_timesteps,
#     203         callback=callback,
#     204         log_interval=log_interval,
#     205         tb_log_name=tb_log_name,
#     206         reset_num_timesteps=reset_num_timesteps,
#     207         progress_bar=progress_bar,
#     208     )
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 with th.no_grad():
#     176     # Convert to pytorch tensor or to TensorDict
#     177     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 178     actions, values, log_probs = self.policy(obs_tensor)
#     179 actions = actions.cpu().numpy()
#     181 # Rescale and perform action
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\stable_baselines3\common\policies.py:645, in ActorCriticPolicy.forward(self, obs, deterministic)
#     643 features = self.extract_features(obs)
#     644 if self.share_features_extractor:
# --> 645     latent_pi, latent_vf = self.mlp_extractor(features)
#     646 else:
#     647     pi_features, vf_features = features
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\stable_baselines3\common\torch_layers.py:222, in MlpExtractor.forward(self, features)
#     217 def forward(self, features: th.Tensor) -> Tuple[th.Tensor, th.Tensor]:
#     218     """
#     219     :return: latent_policy, latent_value of the specified network.
#     220         If all layers are shared, then ``latent_policy == latent_value``
#     221     """
# --> 222     return self.forward_actor(features), self.forward_critic(features)
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\stable_baselines3\common\torch_layers.py:225, in MlpExtractor.forward_actor(self, features)
#     224 def forward_actor(self, features: th.Tensor) -> th.Tensor:
# --> 225     return self.policy_net(features)
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
model_td3 = agent.get_model(model_name="td3")
trained_td3 = agent.train_model(
    model=model_td3, tb_log_name="td3", total_timesteps=50000
)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3\td3_3
# =================================
# begin_total_asset:1000000
# end_total_asset:1769132.1258543723
# Sharpe:  0.7521790785143929
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1870259.5720297936
# Sharpe:  0.7974763042907416
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 45        |
# |    time_elapsed    | 162       |
# |    total_timesteps | 7332      |
# | train/             |           |
# |    actor_loss      | -2.35e+07 |
# |    critic_loss     | 2.22e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5499      |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 38        |
# |    time_elapsed    | 381       |
# |    total_timesteps | 14664     |
# | train/             |           |
# |    actor_loss      | -4.14e+07 |
# |    critic_loss     | 3e+12     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12831     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 36        |
# |    time_elapsed    | 597       |
# |    total_timesteps | 21996     |
# | train/             |           |
# |    actor_loss      | -5.61e+07 |
# |    critic_loss     | 4.95e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20163     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 34        |
# |    time_elapsed    | 842       |
# |    total_timesteps | 29328     |
# | train/             |           |
# |    actor_loss      | -6.82e+07 |
# |    critic_loss     | 7.75e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27495     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 9         |
# |    time_elapsed    | 3938      |
# |    total_timesteps | 36660     |
# | train/             |           |
# |    actor_loss      | -7.82e+07 |
# |    critic_loss     | 1.06e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34827     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 10        |
# |    time_elapsed    | 4207      |
# |    total_timesteps | 43992     |
# | train/             |           |
# |    actor_loss      | -8.62e+07 |
# |    critic_loss     | 9.36e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42159     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 11        |
# |    time_elapsed    | 4489      |
# |    total_timesteps | 51324     |
# | train/             |           |
# |    actor_loss      | -9.28e+07 |
# |    critic_loss     | 1.2e+13   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49491     |
# ----------------------------------

# %%
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo", model_kwargs=PPO_PARAMS)
trained_ppo = agent.train_model(
    model=model_ppo, tb_log_name="ppo", total_timesteps=50000
)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_2
# =================================
# begin_total_asset:1000000
# end_total_asset:1651932.900501427
# Sharpe:  0.6621709498424664
# =================================
# -----------------------------
# | time/              |      |
# |    fps             | 540  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1557231.2312606804
# Sharpe:  0.5857723261487241
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 451       |
# |    iterations           | 2         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.06e+14  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -2.35e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.12e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1766927.148144475
# Sharpe:  0.7387350237574313
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 433       |
# |    iterations           | 3         |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 3.58e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 1.95e+14  |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -1.95e-07 |
# |    std                  | 1         |
# |    value_loss           | 3.98e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1672966.8671302092
# Sharpe:  0.6706726089505411
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 387       |
# |    iterations           | 4         |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 2.38e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.26e+14  |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -1.47e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.48e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1685534.9420081503
# Sharpe:  0.6821896550158788
# =================================
# --------------------------------------
# | time/                   |          |
# |    fps                  | 329      |
# |    iterations           | 5        |
# |    time_elapsed         | 31       |
# |    total_timesteps      | 10240    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.2    |
# |    explained_variance   | 2.98e-07 |
# |    learning_rate        | 0.0001   |
# |    loss                 | 2.21e+14 |
# |    n_updates            | 40       |
# |    policy_gradient_loss | -1.3e-07 |
# |    std                  | 1        |
# |    value_loss           | 4.31e+14 |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2012881.6077941055
# Sharpe:  0.9023020721533975
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 305       |
# |    iterations           | 6         |
# |    time_elapsed         | 40        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.28e+14  |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -2.13e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.61e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1788336.4020342461
# Sharpe:  0.7606541036414685
# =================================
# --------------------------------------
# | time/                   |          |
# |    fps                  | 275      |
# |    iterations           | 7        |
# |    time_elapsed         | 52       |
# |    total_timesteps      | 14336    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.2    |
# |    explained_variance   | 5.96e-08 |
# |    learning_rate        | 0.0001   |
# |    loss                 | 2.6e+14  |
# |    n_updates            | 60       |
# |    policy_gradient_loss | -7e-08   |
# |    std                  | 1        |
# |    value_loss           | 5.43e+14 |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1679025.299784108
# Sharpe:  0.6796644960360431
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 268       |
# |    iterations           | 8         |
# |    time_elapsed         | 60        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.21e+14  |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -8.35e-08 |
# |    std                  | 1         |
# |    value_loss           | 4.56e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1718725.6704064866
# Sharpe:  0.6969698327857852
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1726739.463793055
# Sharpe:  0.7101560629236998
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 267       |
# |    iterations           | 9         |
# |    time_elapsed         | 68        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.25e+14  |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -6.46e-08 |
# |    std                  | 1         |
# |    value_loss           | 4.61e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1830833.3135614053
# Sharpe:  0.7674738060500744
# =================================
# --------------------------------------
# | time/                   |          |
# |    fps                  | 261      |
# |    iterations           | 10       |
# |    time_elapsed         | 78       |
# |    total_timesteps      | 20480    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.2    |
# |    explained_variance   | 1.19e-07 |
# |    learning_rate        | 0.0001   |
# |    loss                 | 2.37e+14 |
# |    n_updates            | 90       |
# |    policy_gradient_loss | -1.5e-07 |
# |    std                  | 1        |
# |    value_loss           | 4.62e+14 |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1581022.925228097
# Sharpe:  0.6107005859498252
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 252       |
# |    iterations           | 11        |
# |    time_elapsed         | 89        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.32e+14  |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -1.56e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.79e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1727807.91585471
# Sharpe:  0.7126386515678911
# =================================
# --------------------------------------
# | time/                   |          |
# |    fps                  | 245      |
# |    iterations           | 12       |
# |    time_elapsed         | 99       |
# |    total_timesteps      | 24576    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -14.2    |
# |    explained_variance   | 1.19e-07 |
# |    learning_rate        | 0.0001   |
# |    loss                 | 1.91e+14 |
# |    n_updates            | 110      |
# |    policy_gradient_loss | -1.2e-07 |
# |    std                  | 1        |
# |    value_loss           | 4.09e+14 |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1728719.198872662
# Sharpe:  0.7203880979760681
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 247       |
# |    iterations           | 13        |
# |    time_elapsed         | 107       |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.31e+14  |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -1.15e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.6e+14   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1812707.5049214463
# Sharpe:  0.7694173517336098
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 252       |
# |    iterations           | 14        |
# |    time_elapsed         | 113       |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.27e+14  |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -1.61e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.68e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1659286.3274353172
# Sharpe:  0.6677881915027214
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 258       |
# |    iterations           | 15        |
# |    time_elapsed         | 119       |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.32e+14  |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -1.09e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.65e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1916744.8103464784
# Sharpe:  0.852377387085129
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 263       |
# |    iterations           | 16        |
# |    time_elapsed         | 124       |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.39e+14  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -1.55e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.65e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1737344.9383895013
# Sharpe:  0.7128874284161709
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 268       |
# |    iterations           | 17        |
# |    time_elapsed         | 129       |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.49e+14  |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -1.55e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.1e+14   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1915355.4432852091
# Sharpe:  0.8278386735668655
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1677107.8698092608
# Sharpe:  0.6806052674397481
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 271       |
# |    iterations           | 18        |
# |    time_elapsed         | 135       |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.97e+14  |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -1.31e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.72e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1899578.644123498
# Sharpe:  0.8237649244414835
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 276       |
# |    iterations           | 19        |
# |    time_elapsed         | 140       |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.06e+14  |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -1.33e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.15e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1688370.861300744
# Sharpe:  0.6862095808382531
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 280       |
# |    iterations           | 20        |
# |    time_elapsed         | 146       |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.59e+14  |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -7.99e-08 |
# |    std                  | 1         |
# |    value_loss           | 5e+14     |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1733115.3162192542
# Sharpe:  0.7218351282060597
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 283       |
# |    iterations           | 21        |
# |    time_elapsed         | 151       |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.09e+14  |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -1.04e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.19e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1609888.143411995
# Sharpe:  0.6328721419492548
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 287       |
# |    iterations           | 22        |
# |    time_elapsed         | 156       |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.17e+14  |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -1.03e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.32e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826110.2909533607
# Sharpe:  0.780603529201689
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 291       |
# |    iterations           | 23        |
# |    time_elapsed         | 161       |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 1.99e+14  |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -1.29e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.13e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1782408.4723155478
# Sharpe:  0.7584230453723976
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 293       |
# |    iterations           | 24        |
# |    time_elapsed         | 167       |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.38e+14  |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -1.18e-07 |
# |    std                  | 1         |
# |    value_loss           | 4.83e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1658291.5908560152
# Sharpe:  0.6579434481040399
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 296       |
# |    iterations           | 25        |
# |    time_elapsed         | 172       |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.15e+14  |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -3.41e-08 |
# |    std                  | 1         |
# |    value_loss           | 4.54e+14  |
# ---------------------------------------

# %%
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}
model_ddpg = agent.get_model("ddpg", model_kwargs=DDPG_PARAMS)
trained_ddpg = agent.train_model(
    model=model_ddpg, tb_log_name="ddpg", total_timesteps=50000
)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_3
# =================================
# begin_total_asset:1000000
# end_total_asset:1734656.4266559158
# Sharpe:  0.730964565443056
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 37        |
# |    time_elapsed    | 193       |
# |    total_timesteps | 7332      |
# | train/             |           |
# |    actor_loss      | -7.24e+07 |
# |    critic_loss     | 7.18e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5499      |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 32        |
# |    time_elapsed    | 453       |
# |    total_timesteps | 14664     |
# | train/             |           |
# |    actor_loss      | -8.74e+07 |
# |    critic_loss     | 6.39e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12831     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 26        |
# |    time_elapsed    | 825       |
# |    total_timesteps | 21996     |
# | train/             |           |
# |    actor_loss      | -9.72e+07 |
# |    critic_loss     | 6.97e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20163     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 26        |
# |    time_elapsed    | 1121      |
# |    total_timesteps | 29328     |
# | train/             |           |
# |    actor_loss      | -1.04e+08 |
# |    critic_loss     | 6.55e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27495     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 26        |
# |    time_elapsed    | 1372      |
# |    total_timesteps | 36660     |
# | train/             |           |
# |    actor_loss      | -1.09e+08 |
# |    critic_loss     | 7.5e+12   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34827     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 27        |
# |    time_elapsed    | 1599      |
# |    total_timesteps | 43992     |
# | train/             |           |
# |    actor_loss      | -1.12e+08 |
# |    critic_loss     | 7.93e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42159     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 26        |
# |    time_elapsed    | 1967      |
# |    total_timesteps | 51324     |
# | train/             |           |
# |    actor_loss      | -1.14e+08 |
# |    critic_loss     | 7.49e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49491     |
# ----------------------------------

# %%
model_sac = agent.get_model("sac")
trained_sac = agent.train_model(
    model=model_ddpg, tb_log_name="sac", total_timesteps=50000
)
# Out:
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/ddpg\sac_1
# =================================
# begin_total_asset:1000000
# end_total_asset:1722442.2637177166
# Sharpe:  0.7040293258790923
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 20        |
# |    time_elapsed    | 366       |
# |    total_timesteps | 7332      |
# | train/             |           |
# |    actor_loss      | -1.16e+08 |
# |    critic_loss     | 8.26e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 56823     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 17        |
# |    time_elapsed    | 829       |
# |    total_timesteps | 14664     |
# | train/             |           |
# |    actor_loss      | -1.17e+08 |
# |    critic_loss     | 9.59e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 64155     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 18        |
# |    time_elapsed    | 1181      |
# |    total_timesteps | 21996     |
# | train/             |           |
# |    actor_loss      | -1.17e+08 |
# |    critic_loss     | 7.33e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 71487     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 20        |
# |    time_elapsed    | 1433      |
# |    total_timesteps | 29328     |
# | train/             |           |
# |    actor_loss      | -1.18e+08 |
# |    critic_loss     | 8.39e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 78819     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 21        |
# |    time_elapsed    | 1674      |
# |    total_timesteps | 36660     |
# | train/             |           |
# |    actor_loss      | -1.18e+08 |
# |    critic_loss     | 7.78e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 86151     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 22        |
# |    time_elapsed    | 1940      |
# |    total_timesteps | 43992     |
# | train/             |           |
# |    actor_loss      | -1.18e+08 |
# |    critic_loss     | 7.9e+12   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 93483     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 10        |
# |    time_elapsed    | 4896      |
# |    total_timesteps | 51324     |
# | train/             |           |
# |    actor_loss      | -1.18e+08 |
# |    critic_loss     | 9.11e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 100815    |
# ----------------------------------

# %%
e_trade_gym = PortfolioEnv(df=train_data, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()
# Out:
# c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
a2c_train_daily_return, a2c_train_weights = DRLAgent.DRL_prediction(
    model=trained_a2c, test_data=train_data, test_env=env_trade, test_obs=obs_trade
)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1272043.3165570383
# Sharpe:  1.0462973085071683
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1222033.1043392965
# Sharpe:  0.8778147391426899
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1279871.6411852527
# Sharpe:  1.0654127617642157
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1276636.9796915755
# Sharpe:  1.069993586857756
# =================================

# %%
td3_train_daily_return, td3_train_weights = DRLAgent.DRL_prediction(
    model=trained_td3, test_data=train_data, test_env=env_trade, test_obs=obs_trade
)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:2013421.311170009
# Sharpe:  0.8517854499796963
# =================================

# %%
ppo_train_daily_return, ppo_train_weights = DRLAgent.DRL_prediction(
    model=trained_ppo, test_data=train_data, test_env=env_trade, test_obs=obs_trade
)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1626097.5188569683
# Sharpe:  0.640187544979409
# =================================

# %%
ddpg_train_daily_return, ddpg_train_weights = DRLAgent.DRL_prediction(
    model=trained_ddpg, test_data=train_data, test_env=env_trade, test_obs=obs_trade
)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================

# %%
sac_train_daily_return, sac_train_weights = DRLAgent.DRL_prediction(
    model=trained_sac, test_data=train_data, test_env=env_trade, test_obs=obs_trade
)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1729913.4481301957
# Sharpe:  0.7092739636196487
# =================================

# %%
# %store a2c_train_daily_return
# %store td3_train_daily_return
# %store ppo_train_daily_return
# %store ddpg_train_daily_return
# %store sac_train_daily_return
# Out:
# Stored 'a2c_train_daily_return' (DataFrame)
# Stored 'td3_train_daily_return' (DataFrame)
# Stored 'ppo_train_daily_return' (DataFrame)
# Stored 'ddpg_train_daily_return' (DataFrame)
# Stored 'sac_train_daily_return' (DataFrame)

# %%
e_trade_gym = PortfolioEnv(df=test_data, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()
result_dir = ""
# %store -r result_dir
# Out:
# c:\Users\wyh21\.conda\envs\PoOpt\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
a2c_test_daily_return, a2c_test_weights = DRLAgent.DRL_prediction(
    model=trained_a2c, test_data=test_data, test_env=env_trade, test_obs=obs_trade
)
a2c_test_weights.to_csv(f"{result_dir}/a2c_test_weights.csv")
a2c_test_daily_return
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1196048.7717550308
# Sharpe:  0.7959931541665689
# =================================
#            date  daily_return
# 0    2022-01-04      0.000000
# 1    2022-01-05     -0.012397
# 2    2022-01-06     -0.005700
# 3    2022-01-07     -0.001576
# 4    2022-01-10      0.004201
# ..          ...           ...
# 458  2023-12-26      0.000185
# 459  2023-12-27      0.004008
# 460  2023-12-28     -0.003290
# 461  2023-12-29     -0.002445
# 462  2023-12-31     -0.000009
#
# [463 rows x 2 columns]

# %%
td3_test_daily_return, td3_test_weights = DRLAgent.DRL_prediction(
    model=trained_td3, test_data=test_data, test_env=env_trade, test_obs=obs_trade
)
td3_test_weights.to_csv(f"{result_dir}/td3_test_weights.csv")
td3_test_daily_return
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1173382.1588731797
# Sharpe:  0.6171842665016268
# =================================
#            date  daily_return
# 0    2022-01-04      0.000000
# 1    2022-01-05     -0.020528
# 2    2022-01-06     -0.005435
# 3    2022-01-07     -0.005633
# 4    2022-01-10      0.002370
# ..          ...           ...
# 458  2023-12-26      0.002060
# 459  2023-12-27      0.004193
# 460  2023-12-28     -0.001140
# 461  2023-12-29     -0.003649
# 462  2023-12-31     -0.000011
#
# [463 rows x 2 columns]

# %%
ppo_test_daily_return, ppo_test_weights = DRLAgent.DRL_prediction(
    model=trained_ppo, test_data=test_data, test_env=env_trade, test_obs=obs_trade
)
ppo_test_weights.to_csv(f"{result_dir}/ppo_test_weights.csv")
ppo_test_daily_return
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1182706.142690362
# Sharpe:  0.7209991786526097
# =================================
#            date  daily_return
# 0    2022-01-04      0.000000
# 1    2022-01-05     -0.018331
# 2    2022-01-06     -0.007042
# 3    2022-01-07     -0.004906
# 4    2022-01-10      0.002878
# ..          ...           ...
# 458  2023-12-26      0.001015
# 459  2023-12-27      0.004280
# 460  2023-12-28     -0.001175
# 461  2023-12-29     -0.003506
# 462  2023-12-31     -0.000013
#
# [463 rows x 2 columns]

# %%
ddpg_test_daily_return, ddpg_test_weights = DRLAgent.DRL_prediction(
    model=trained_ddpg, test_data=test_data, test_env=env_trade, test_obs=obs_trade
)
ddpg_test_weights.to_csv(f"{result_dir}/ddpg_test_weights.csv")
ddpg_test_daily_return
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1180114.4907159419
# Sharpe:  0.6674930947753017
# =================================
#            date  daily_return
# 0    2022-01-04      0.000000
# 1    2022-01-05     -0.018653
# 2    2022-01-06     -0.005466
# 3    2022-01-07     -0.006562
# 4    2022-01-10      0.002528
# ..          ...           ...
# 458  2023-12-26     -0.001404
# 459  2023-12-27      0.003835
# 460  2023-12-28      0.000189
# 461  2023-12-29     -0.001118
# 462  2023-12-31     -0.000010
#
# [463 rows x 2 columns]

# %%
sac_test_daily_return, sac_test_weights = DRLAgent.DRL_prediction(
    model=trained_sac, test_data=test_data, test_env=env_trade, test_obs=obs_trade
)
sac_test_weights.to_csv(f"{result_dir}/sac_test_weights.csv")
sac_test_daily_return
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1180114.4907159419
# Sharpe:  0.6674930947753017
# =================================
#            date  daily_return
# 0    2022-01-04      0.000000
# 1    2022-01-05     -0.018653
# 2    2022-01-06     -0.005466
# 3    2022-01-07     -0.006562
# 4    2022-01-10      0.002528
# ..          ...           ...
# 458  2023-12-26     -0.001404
# 459  2023-12-27      0.003835
# 460  2023-12-28      0.000189
# 461  2023-12-29     -0.001118
# 462  2023-12-31     -0.000010
#
# [463 rows x 2 columns]

# %%
a2c_test_portfolio = a2c_test_daily_return.copy()
a2c_test_returns = a2c_test_daily_return.copy()

td3_test_portfolio = td3_test_daily_return.copy()
td3_test_returns = td3_test_daily_return.copy()

ppo_test_portfolio = ppo_test_daily_return.copy()
ppo_test_returns = ppo_test_daily_return.copy()

ddpg_test_portfolio = ddpg_test_daily_return.copy()
ddpg_test_returns = ddpg_test_daily_return.copy()

sac_test_portfolio = sac_test_daily_return.copy()
sac_test_returns = sac_test_daily_return.copy()

# %store a2c_test_portfolio
# %store a2c_test_returns 

# %store td3_test_portfolio
# %store td3_test_returns 

# %store ppo_test_portfolio
# %store ppo_test_returns 

# %store ddpg_test_portfolio
# %store ddpg_test_returns 

# %store sac_test_portfolio
# %store sac_test_returns
# Out:
# Stored 'a2c_test_portfolio' (DataFrame)
# Stored 'a2c_test_returns' (DataFrame)
# Stored 'td3_test_portfolio' (DataFrame)
# Stored 'td3_test_returns' (DataFrame)
# Stored 'ppo_test_portfolio' (DataFrame)
# Stored 'ppo_test_returns' (DataFrame)
# Stored 'ddpg_test_portfolio' (DataFrame)
# Stored 'ddpg_test_returns' (DataFrame)
# Stored 'sac_test_portfolio' (DataFrame)
# Stored 'sac_test_returns' (DataFrame)
